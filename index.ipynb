# %% [markdown]
# # Seaborn - Lab
#
# ## Introduction
#
# In this lab, we'll get some practice working with a second, more advanced visualization library, **_Seaborn_**!
#
# ## Objectives
#
# You will be able to:
#
# * Understand the relationship between Seaborn and Matplotlib, and when to use each
# * Create basic visualizations with Seaborn
#
# ## Getting Started
#
# In this lab, we'll explore several different kinds of visualizations we can create with Seaborn. Seaborn is built on top of Matplotlib, so you'll find that it will feel quite familiar.
#
# Let's get started by importing some things and creating a toy dataset to work with for our first visualization.
#
#
# In the cell below:
#
# * Import `numpy` and set the standard alias of `np`
# * Import `seaborn` and set the standard alias of `sns`
# * Set `%matplotlib inline` so that our visualizations appear in the notebook, and not as separate files

# %%
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Great! Now, run the cell below to create a sample dataset.

# %%
np.random.normal(size=(20, 10)).shape
# Out:
# (20, 10)

# %%
np.arange(10).shape
# Out:
# (10,)

# %%
data = np.random.normal(size=(20, 10)) + np.arange(10) / 2

# %% [markdown]
# ### Basic Visualiations with Seaborn
#
# We'll start off by creating a boxplot with the dataset we just created so that we can get a feel for the common workflow of Seaborn.
#
# In the cell below:
#
# * Create a `boxplot` and pass in the parameter `data=data`. Store the object returned in the variable `boxplot`

# %%
boxplot = sns.boxplot(data=data)

# %% [markdown]
# That's a nice looking visualization, for only a single line of code! However, it's missing axis labels and a title. Let's fix that.
#
# In the cell below:
#
# * Copy and paste the code from the cell above to recreate our boxplot
# * Call the `boxplot` object's `set()` method and pass in the following parameters:
#     * `xlabel= 'X Label'`
#     * `ylabel= 'Y Label'`
#     * `title = 'Example Boxplot'`

# %%
boxplot = sns.boxplot(data=data)
boxplot.set(xlabel = 'X Label', ylabel = 'Y Label', title = 'Example Boxplot')
# Out:
# [Text(0, 0.5, 'Y Label'),
#  Text(0.5, 0, 'X Label'),
#  Text(0.5, 1.0, 'Example Boxplot')]

# %% [markdown]
# That wasn't too bad! Note that we can also use **_Method Chaining_** to set all the label and title information by combining the two lines in the cell above!
#
# In the cell below:
#
# * Recreate the labeled boxplot by calling `.set()` and passing in the appropriate parameter values immediately after calling `sns.boxplot(data=data)` to create the visualization.
#
# **_NOTE_**: For this visualization, you do not need to store the object in a variable. Just call the methods.

# %%
boxplot = sns.boxplot(data=data).set(xlabel = 'X Label', ylabel = 'Y Label', title = 'Example Boxplot')

# %% [markdown]
# Great! As you can see, Seaborn is a pretty easy library to work with. It also has very detailed and easy-to-follow documentation, complete with a ton of examples and tutorials. If you're ever unsure of how to build something, don't be afraid to look at the [Seaborn Documentation](https://seaborn.pydata.org/), or Google!
#
# ### Changing Style and Context
#
# One of the main reasons Data Scientists love Seaborn is because the visualizations it creates are just plain prettier than those made by matplotlib. Seaborn makes it very simple to style our visualizations--all we need to do is use the `set_style()` method!
#
# In the cell below:
#
# * Call Seaborn's `set_style()` method and pass in the string `'darkgrid'`.
# * Recreate the labeled boxplot that we made in the cell above.

# %%
sns.set_style('darkgrid')
boxplot = sns.boxplot(data=data).set(xlabel = 'X Label', ylabel = 'Y Label', title = 'Example Boxplot')

# %% [markdown]
# That's much easier to read! There are several different styles that we can choose from. To see examples of the different styles we can use, check out the [documentation](https://seaborn.pydata.org/tutorial/aesthetics.html) for controlling figure aesthetics.
#
# Before we move on, let's make one more change. While the plot looks much better now, the size of the text for ticks and axis labels so small that it would be hard for people to read it unless they're right in front of the monitor--that's a problem, if the visualizations are going to be used in something like a tech talk or presentation!
#
# For this reason, we can also set the context, using the--you guessed it--`set_context()` method!
#
# In the cell below:
#
# * Call Seaborn's `set_context()` method and pass in the string `'poster'`.
# * Recreate the labeled boxplot that we made in the cell above.

# %%
sns.set_context('poster')
boxplot = sns.boxplot(data=data).set(xlabel = 'X Label', ylabel = 'Y Label', title = 'Example Boxplot')

# %% [markdown]
# Much better! That's much more readable. From smallest to largest, the different context settings we can use are `'paper'`, `'notebook'`, `'talk'`, and `'poster'`.
#
# ### A  Quick Note on Contexts and Styles
#
# When you call `set_context` or `set_style`, you're setting a global parameter that will apply to all future plots you create during this session. Any visualizations you have already created will not change--however, they will change if you rerun the cell that created them!
#
# Let's change our context back to `'notebook'` so that the next visualizations we create don't look too big.
#
# In the cell below, change the context back to `'notebook'`.

# %%
sns.set_context('notebook')
boxplot = sns.boxplot(data=data).set(xlabel = 'X Label', ylabel = 'Y Label', title = 'Example Boxplot')

# %% [markdown]
# ## More Advanced Visualizations
#
# One awesome feature of Seaborn is the ability to quickly and easily create advanced visualizations such as **_Regression Plots_**. To end this lab, we'll see a few examples, and explore how they are created.
#
# ### Regression Lines with Confidence Intervals
#
# There are also several different types of regression plots Seaborn makes available for this purpose. For this example, we're going to create an advanced regression plot that also visualizes the confidence interval for our regression line. We'll even have the visualization **_condition on_** a 3rd variable, to show how the regression lines differ for each group, depending on the value of the 3rd variable.
#
# For this visualization, we'll need a more advanced dataset than the example we created and used above. Luckily, Seaborn comes with some preloaded datasets. We can see the names of all the datasets by calling Seaborn's `get_dataset_names()` method.
#
# Do this now in the cell below.

# %%
sns.get_dataset_names()
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/seaborn/utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file /opt/conda/envs/learn-env/lib/python3.6/site-packages/seaborn/utils.py. To get rid of this warning, pass the additional argument 'features="html5lib"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# Great! For the reamainder of this notebook, we'll use the `'tips'` dataset. We can get this dataset by calling Seaborn's `load_dataset()` method and passing in the string `'tips'`. Seaborn is even considerate enough to return the dataset as a pandas DataFrame!
#
# In the cell below, get the tips dataset and store it in the variable `tips`. Then, display the head of the DataFrame so we can see what we're working with.

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Now that we have our dataset, we can create our regression plot. There are several kinds of regression plots we can use. For this example, we'll use the `lmplot` function.
#
# In the cell below:
#
# * Call Seaborn's `lmplot` function and pass in the following arguments:
#     * `x='total_bill'`
#     * `y='tip'`
#     * `hue='smoker'`
#     * `data= tips`

# %%
# Out:
# /bin/sh: 1: y: not found

# %%
# !conda update --all -y
# Out:
# Collecting package metadata: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.6.14
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/learn-env
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB  defaults
#     _py-xgboost-mutex-2.0      |            cpu_0           8 KB  conda-forge
#     alembic-1.1.0              |             py_0          98 KB  conda-forge
#     asn1crypto-0.24.0          |        py36_1003         154 KB  conda-forge
#     async_generator-1.10       |             py_0          18 KB  conda-forge
#     attrs-19.1.0               |             py_0          32 KB  conda-forge
#     backcall-0.1.0             |             py_0          13 KB  conda-forge
#     beautifulsoup4-4.8.0       |           py36_0         144 KB  conda-forge
#     blas-1.0                   |         openblas           1 KB  conda-forge
#     bleach-3.1.0               |             py_0         110 KB  conda-forge
#     blinker-1.4                |             py_1          13 KB  conda-forge
#     boto-2.49.0                |             py_0         838 KB  conda-forge
#     boto3-1.9.224              |             py_0          69 KB  conda-forge
#     botocore-1.12.224          |             py_0         3.4 MB  conda-forge
#     bz2file-0.98               |             py_0           9 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     cairo-1.16.0               |    hfb77d84_1002         1.5 MB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     certipy-0.1.3              |             py_0          17 KB  conda-forge
#     cffi-1.12.3                |   py36h8022711_0         218 KB  conda-forge
#     chardet-3.0.4              |        py36_1003         190 KB  conda-forge
#     configurable-http-proxy-4.1.0|         node11_1         866 KB  conda-forge
#     cryptography-2.7           |   py36h72c5cf5_0         607 KB  conda-forge
#     cryptography-vectors-2.7   |             py_0        30.6 MB  conda-forge
#     cycler-0.10.0              |             py_1           8 KB  conda-forge
#     cython-0.29.13             |   py36he1b5a44_0         2.2 MB  conda-forge
#     dbus-1.13.6                |       he372182_0         602 KB  conda-forge
#     decorator-4.4.0            |             py_0          11 KB  conda-forge
#     defusedxml-0.5.0           |             py_1          20 KB  conda-forge
#     docutils-0.15.2            |           py36_0         736 KB  conda-forge
#     entrypoints-0.3            |        py36_1000          12 KB  conda-forge
#     expat-2.2.5                |    he1b5a44_1003         191 KB  conda-forge
#     fontconfig-2.13.1          |    h86ecdb6_1001         340 KB  conda-forge
#     freetype-2.10.0            |       he983fc9_1         884 KB  conda-forge
#     fribidi-1.0.5              |    h516909a_1002         112 KB  conda-forge
#     gensim-3.7.3               |   py36he1b5a44_1        22.7 MB  conda-forge
#     gettext-0.19.8.1           |    hc5be6a0_1002         3.6 MB  conda-forge
#     glib-2.58.3                |    h6f030ca_1002         3.3 MB  conda-forge
#     gmp-6.1.2                  |    hf484d3e_1000         751 KB  conda-forge
#     graphite2-1.3.13           |    hf484d3e_1000         109 KB  conda-forge
#     graphviz-2.40.1            |       h0f2764d_1         6.4 MB  conda-forge
#     gst-plugins-base-1.14.5    |       h0935bb2_0         6.8 MB  conda-forge
#     gstreamer-1.14.5           |       h36ae1b5_0         4.5 MB  conda-forge
#     h5py-2.9.0                 |nompi_py36h513d04c_1104         1.2 MB  conda-forge
#     harfbuzz-2.4.0             |       h9f30f68_3         1.5 MB  conda-forge
#     hdf5-1.10.5                |nompi_h3c11f04_1103         3.1 MB  conda-forge
#     icu-64.2                   |       he1b5a44_1        12.6 MB  conda-forge
#     idna-2.8                   |        py36_1000         132 KB  conda-forge
#     intel-openmp-2019.4        |              243         876 KB  defaults
#     ipykernel-5.1.2            |   py36h5ca1d4c_0         159 KB  conda-forge
#     ipython-7.8.0              |   py36h5ca1d4c_0         1.1 MB  conda-forge
#     ipython_genutils-0.2.0     |             py_1          21 KB  conda-forge
#     jedi-0.15.1                |           py36_0         717 KB  conda-forge
#     jinja2-2.10.1              |             py_0          91 KB  conda-forge
#     jmespath-0.9.4             |             py_0          20 KB  conda-forge
#     joblib-0.13.2              |             py_0         180 KB  conda-forge
#     jpeg-9c                    |    h14c3975_1001         251 KB  conda-forge
#     json5-0.8.5                |             py_0          24 KB  conda-forge
#     jsonschema-3.0.2           |           py36_0          87 KB  conda-forge
#     jupyter_client-5.3.1       |             py_0          64 KB  conda-forge
#     jupyter_core-4.4.0         |             py_0          44 KB  conda-forge
#     jupyterhub-1.0.0           |           py36_0         1.8 MB  conda-forge
#     jupyterlab-1.1.2           |             py_0        11.7 MB  conda-forge
#     jupyterlab_launcher-0.13.1 |             py_2          20 KB  conda-forge
#     jupyterlab_server-1.0.6    |             py_0          23 KB  conda-forge
#     kiwisolver-1.1.0           |   py36hc9558a2_0          86 KB  conda-forge
#     krb5-1.16.3                |    h05b26f9_1001         1.4 MB  conda-forge
#     libblas-3.8.0              |7_h6e990d7_netlib         181 KB  conda-forge
#     libcblas-3.8.0             |7_h6e990d7_netlib          47 KB  conda-forge
#     libcurl-7.65.3             |       hda55be3_0         575 KB  conda-forge
#     libgcc-7.2.0               |       h69d50b8_2         304 KB  conda-forge
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB  defaults
#     libiconv-1.15              |    h516909a_1005         2.0 MB  conda-forge
#     liblapack-3.8.0            |7_h6e990d7_netlib         2.9 MB  conda-forge
#     libopenblas-0.3.2          |       h5a2b251_1         7.7 MB  defaults
#     libpng-1.6.37              |       hed695b0_0         343 KB  conda-forge
#     libsodium-1.0.17           |       h516909a_0         330 KB  conda-forge
#     libssh2-1.8.2              |       h22169c7_2         257 KB  conda-forge
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB  defaults
#     libtiff-4.0.10             |    h57b8799_1003         587 KB  conda-forge
#     libtool-2.4.6              |    h14c3975_1002         512 KB  conda-forge
#     libuuid-2.32.1             |    h14c3975_1000          26 KB  conda-forge
#     libxcb-1.13                |    h14c3975_1002         396 KB  conda-forge
#     libxgboost-0.90            |       he1b5a44_2         2.4 MB  conda-forge
#     libxml2-2.9.9              |       hee79883_5         1.3 MB  conda-forge
#     lz4-c-1.8.3                |    he1b5a44_1001         187 KB  conda-forge
#     mako-1.1.0                 |             py_0          57 KB  conda-forge
#     markupsafe-1.1.1           |   py36h14c3975_0          26 KB  conda-forge
#     matplotlib-3.1.1           |           py36_1           6 KB  conda-forge
#     matplotlib-base-3.1.1      |   py36he7580a8_1         6.7 MB  conda-forge
#     mistune-0.8.4              |py36h14c3975_1000          53 KB  conda-forge
#     mkl-2019.4                 |              243       204.1 MB  defaults
#     mkl-service-2.3.0          |   py36h516909a_0          64 KB  conda-forge
#     mkl_fft-1.0.14             |   py36h516909a_1         170 KB  conda-forge
#     mkl_random-1.1.0           |   py36hb3f55d8_0         366 KB  conda-forge
#     nb_conda-2.2.1             |           py36_2          35 KB  conda-forge
#     nb_conda_kernels-2.2.2     |           py36_0          32 KB  conda-forge
#     nbconvert-5.6.0            |           py36_1         465 KB  conda-forge
#     nbformat-4.4.0             |             py_1          91 KB  conda-forge
#     networkx-2.3               |             py_0         1.1 MB  conda-forge
#     nltk-3.4.4                 |             py_0         1.1 MB  conda-forge
#     nodejs-11.14.0             |       he1b5a44_1        16.6 MB  conda-forge
#     notebook-6.0.1             |           py36_0         6.0 MB  conda-forge
#     numpy-1.17.2               |   py36h95a1406_0         5.2 MB  conda-forge
#     numpy-base-1.15.0          |   py36hc937464_0         4.1 MB  defaults
#     oauthlib-3.0.1             |             py_0          82 KB  conda-forge
#     openblas-0.3.4             |    h9ac9557_1000        15.8 MB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     pamela-1.0.0               |             py_0           9 KB  conda-forge
#     pandas-0.25.1              |   py36hb3f55d8_0        11.4 MB  conda-forge
#     pandoc-2.7.3               |                0        22.4 MB  conda-forge
#     pandocfilters-1.4.2        |             py_1           9 KB  conda-forge
#     pango-1.42.4               |       ha030887_1         517 KB  conda-forge
#     parso-0.5.1                |             py_0          65 KB  conda-forge
#     patsy-0.5.1                |             py_0         187 KB  conda-forge
#     pcre-8.41                  |    hf484d3e_1003         249 KB  conda-forge
#     pexpect-4.7.0              |           py36_0          78 KB  conda-forge
#     pickleshare-0.7.5          |        py36_1000          12 KB  conda-forge
#     pip-19.2.3                 |           py36_0         1.9 MB  conda-forge
#     pixman-0.38.0              |    h516909a_1003         594 KB  conda-forge
#     plotly-4.1.1               |             py_0         4.0 MB  conda-forge
#     prometheus_client-0.7.1    |             py_0          38 KB  conda-forge
#     prompt_toolkit-2.0.9       |             py_0         222 KB  conda-forge
#     pthread-stubs-0.4          |    h14c3975_1001           5 KB  conda-forge
#     ptyprocess-0.6.0           |          py_1001          15 KB  conda-forge
#     py-xgboost-0.90            |   py36he1b5a44_2          73 KB  conda-forge
#     py4j-0.10.7                |             py_1         177 KB  conda-forge
#     pycparser-2.19             |           py36_1         173 KB  conda-forge
#     pycurl-7.43.0.2            |   py36h16ce93b_1          68 KB  conda-forge
#     pydotplus-2.0.2            |     pyhd1c1de3_3          23 KB  conda-forge
#     pygments-2.4.2             |             py_0         661 KB  conda-forge
#     pyjwt-1.7.1                |             py_0          17 KB  conda-forge
#     pyopenssl-19.0.0           |           py36_0          81 KB  conda-forge
#     pyparsing-2.4.2            |             py_0          57 KB  conda-forge
#     pyqt-5.9.2                 |   py36hcca6a23_3         5.7 MB  conda-forge
#     pyrsistent-0.15.4          |   py36h516909a_0          89 KB  conda-forge
#     pysocks-1.7.0              |           py36_0          26 KB  conda-forge
#     pyspark-2.4.4              |             py_0       204.9 MB  conda-forge
#     python-3.6.7               |    h357f687_1005        34.6 MB  conda-forge
#     python-dateutil-2.8.0      |             py_0         219 KB  conda-forge
#     python-editor-1.0.4        |             py_0           9 KB  conda-forge
#     python-oauth2-1.1.1        |             py_0          40 KB  conda-forge
#     pytz-2019.2                |             py_0         228 KB  conda-forge
#     pyzmq-18.0.2               |   py36h1768529_2         513 KB  conda-forge
#     qt-5.9.7                   |       h0c104cb_3        80.8 MB  conda-forge
#     readline-8.0               |       hf8c457e_0         441 KB  conda-forge
#     requests-2.22.0            |           py36_1          84 KB  conda-forge
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     s3transfer-0.2.1           |           py36_0          91 KB  conda-forge
#     scikit-learn-0.21.3        |   py36hcdab131_0         6.7 MB  conda-forge
#     scipy-1.3.1                |   py36h921218d_2        18.1 MB  conda-forge
#     seaborn-0.9.0              |             py_1         163 KB  conda-forge
#     send2trash-1.5.0           |             py_0          12 KB  conda-forge
#     setuptools-41.2.0          |           py36_0         634 KB  conda-forge
#     simplegeneric-0.8.1        |             py_1           7 KB  conda-forge
#     sip-4.19.8                 |py36hf484d3e_1000         290 KB  conda-forge
#     six-1.12.0                 |        py36_1000          22 KB  conda-forge
#     smart_open-1.8.4           |             py_0          53 KB  conda-forge
#     soupsieve-1.9.3            |           py36_0          57 KB  conda-forge
#     sqlalchemy-1.3.8           |   py36h516909a_0         1.7 MB  conda-forge
#     sqlite-3.29.0              |       hcee41ef_1         1.9 MB  conda-forge
#     statsmodels-0.10.1         |   py36hc1659b7_0         9.6 MB  conda-forge
#     terminado-0.8.2            |           py36_0          23 KB  conda-forge
#     testpath-0.4.2             |          py_1001          85 KB  conda-forge
#     tk-8.6.9                   |    hed695b0_1002         3.2 MB  conda-forge
#     tornado-6.0.3              |   py36h516909a_0         636 KB  conda-forge
#     tqdm-4.35.0                |             py_0          42 KB  conda-forge
#     traitlets-4.3.2            |        py36_1000         131 KB  conda-forge
#     urllib3-1.25.3             |           py36_0         187 KB  conda-forge
#     wcwidth-0.1.7              |             py_1          17 KB  conda-forge
#     webencodings-0.5.1         |             py_1          12 KB  conda-forge
#     wheel-0.33.6               |           py36_0          35 KB  conda-forge
#     xlrd-1.2.0                 |             py_0         108 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h14c3975_1002          26 KB  conda-forge
#     xorg-libice-1.0.10         |       h516909a_0          57 KB  conda-forge
#     xorg-libsm-1.2.3           |    h84519dc_1000          25 KB  conda-forge
#     xorg-libx11-1.6.8          |       h516909a_0         907 KB  conda-forge
#     xorg-libxau-1.0.9          |       h14c3975_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h516909a_0          18 KB  conda-forge
#     xorg-libxext-1.3.4         |       h516909a_0          51 KB  conda-forge
#     xorg-libxpm-3.5.12         |    h516909a_1002          63 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h516909a_1002          31 KB  conda-forge
#     xorg-libxt-1.1.5           |    h516909a_1003         367 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h14c3975_1002           8 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h14c3975_1002          27 KB  conda-forge
#     xorg-xproto-7.0.31         |    h14c3975_1007          72 KB  conda-forge
#     zeromq-4.3.2               |       he1b5a44_2         668 KB  conda-forge
#     zlib-1.2.11                |    h516909a_1005         105 KB  conda-forge
#     zstd-1.4.0                 |       h3b9ef0a_0         928 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       843.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   async_generator    conda-forge/noarch::async_generator-1.10-py_0
#   attrs              conda-forge/noarch::attrs-19.1.0-py_0
#   blinker            conda-forge/noarch::blinker-1.4-py_1
#   cairo              conda-forge/linux-64::cairo-1.16.0-hfb77d84_1002
#   certipy            conda-forge/noarch::certipy-0.1.3-py_0
#   fribidi            conda-forge/linux-64::fribidi-1.0.5-h516909a_1002
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-hc5be6a0_1002
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-hf484d3e_1000
#   graphviz           conda-forge/linux-64::graphviz-2.40.1-h0f2764d_1
#   harfbuzz           conda-forge/linux-64::harfbuzz-2.4.0-h9f30f68_3
#   joblib             conda-forge/noarch::joblib-0.13.2-py_0
#   json5              conda-forge/noarch::json5-0.8.5-py_0
#   jupyterlab_server  conda-forge/noarch::jupyterlab_server-1.0.6-py_0
#   krb5               conda-forge/linux-64::krb5-1.16.3-h05b26f9_1001
#   libblas            conda-forge/linux-64::libblas-3.8.0-7_h6e990d7_netlib
#   libcblas           conda-forge/linux-64::libcblas-3.8.0-7_h6e990d7_netlib
#   libcurl            conda-forge/linux-64::libcurl-7.65.3-hda55be3_0
#   libiconv           conda-forge/linux-64::libiconv-1.15-h516909a_1005
#   liblapack          conda-forge/linux-64::liblapack-3.8.0-7_h6e990d7_netlib
#   libopenblas        pkgs/main/linux-64::libopenblas-0.3.2-h5a2b251_1
#   libssh2            conda-forge/linux-64::libssh2-1.8.2-h22169c7_2
#   libtiff            conda-forge/linux-64::libtiff-4.0.10-h57b8799_1003
#   libtool            conda-forge/linux-64::libtool-2.4.6-h14c3975_1002
#   lz4-c              conda-forge/linux-64::lz4-c-1.8.3-he1b5a44_1001
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.1.1-py36he7580a8_1
#   mkl-service        conda-forge/linux-64::mkl-service-2.3.0-py36h516909a_0
#   oauthlib           conda-forge/noarch::oauthlib-3.0.1-py_0
#   openblas           conda-forge/linux-64::openblas-0.3.4-h9ac9557_1000
#   pango              conda-forge/linux-64::pango-1.42.4-ha030887_1
#   pixman             conda-forge/linux-64::pixman-0.38.0-h516909a_1003
#   prometheus_client  conda-forge/noarch::prometheus_client-0.7.1-py_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h14c3975_1001
#   pycurl             conda-forge/linux-64::pycurl-7.43.0.2-py36h16ce93b_1
#   pyjwt              conda-forge/noarch::pyjwt-1.7.1-py_0
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.15.4-py36h516909a_0
#   send2trash         conda-forge/noarch::send2trash-1.5.0-py_0
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h14c3975_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h516909a_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-h84519dc_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.6.8-h516909a_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h14c3975_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h516909a_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h516909a_0
#   xorg-libxpm        conda-forge/linux-64::xorg-libxpm-3.5.12-h516909a_1002
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h516909a_1002
#   xorg-libxt         conda-forge/linux-64::xorg-libxt-1.1.5-h516909a_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h14c3975_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h14c3975_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h14c3975_1007
#   zstd               conda-forge/linux-64::zstd-1.4.0-h3b9ef0a_0
#
# The following packages will be UPDATED:
#
#   _py-xgboost-mutex                               pkgs/main --> conda-forge
#   alembic            pkgs/main/linux-64::alembic-1.0.9-py3~ --> conda-forge/noarch::alembic-1.1.0-py_0
#   asn1crypto            pkgs/main::asn1crypto-0.24.0-py36_0 --> conda-forge::asn1crypto-0.24.0-py36_1003
#   beautifulsoup4     pkgs/main::beautifulsoup4-4.7.1-py36_1 --> conda-forge::beautifulsoup4-4.8.0-py36_0
#   boto3                       pkgs/main::boto3-1.9.134-py_0 --> conda-forge::boto3-1.9.224-py_0
#   botocore                pkgs/main::botocore-1.12.134-py_0 --> conda-forge::botocore-1.12.224-py_0
#   ca-certificates    pkgs/main::ca-certificates-2018.03.07~ --> conda-forge::ca-certificates-2019.6.16-hecc5488_0
#   certifi               pkgs/main::certifi-2018.8.13-py36_0 --> conda-forge::certifi-2019.6.16-py36_1
#   cffi                pkgs/main::cffi-1.11.5-py36he75722e_1 --> conda-forge::cffi-1.12.3-py36h8022711_0
#   chardet                   pkgs/main::chardet-3.0.4-py36_1 --> conda-forge::chardet-3.0.4-py36_1003
#   configurable-http~ pkgs/main::configurable-http-proxy-4.~ --> conda-forge::configurable-http-proxy-4.1.0-node11_1
#   cryptography       pkgs/main::cryptography-2.3.1-py36hc3~ --> conda-forge::cryptography-2.7-py36h72c5cf5_0
#   cryptography-vect~ pkgs/main/linux-64::cryptography-vect~ --> conda-forge/noarch::cryptography-vectors-2.7-py_0
#   cycler             pkgs/main/linux-64::cycler-0.10.0-py3~ --> conda-forge/noarch::cycler-0.10.0-py_1
#   cython             pkgs/main::cython-0.28.5-py36hf484d3e~ --> conda-forge::cython-0.29.13-py36he1b5a44_0
#   decorator          pkgs/main/linux-64::decorator-4.3.0-p~ --> conda-forge/noarch::decorator-4.4.0-py_0
#   docutils                  pkgs/main::docutils-0.14-py36_0 --> conda-forge::docutils-0.15.2-py36_0
#   entrypoints             pkgs/main::entrypoints-0.3-py36_0 --> conda-forge::entrypoints-0.3-py36_1000
#   fontconfig         pkgs/main::fontconfig-2.13.0-h9420a91~ --> conda-forge::fontconfig-2.13.1-h86ecdb6_1001
#   freetype             pkgs/main::freetype-2.9.1-h8a8886c_1 --> conda-forge::freetype-2.10.0-he983fc9_1
#   gensim             pkgs/main::gensim-3.4.0-py36h14c3975_0 --> conda-forge::gensim-3.7.3-py36he1b5a44_1
#   glib                    pkgs/main::glib-2.56.2-hd408876_0 --> conda-forge::glib-2.58.3-h6f030ca_1002
#   gmp                       pkgs/main::gmp-6.1.2-h6c8ec71_1 --> conda-forge::gmp-6.1.2-hf484d3e_1000
#   gst-plugins-base   pkgs/main::gst-plugins-base-1.14.0-hb~ --> conda-forge::gst-plugins-base-1.14.5-h0935bb2_0
#   gstreamer          pkgs/main::gstreamer-1.14.0-hb453b48_1 --> conda-forge::gstreamer-1.14.5-h36ae1b5_0
#   h5py                 pkgs/main::h5py-2.9.0-py36h7918eee_0 --> conda-forge::h5py-2.9.0-nompi_py36h513d04c_1104
#   hdf5                    pkgs/main::hdf5-1.10.4-hb1b8bf9_0 --> conda-forge::hdf5-1.10.5-nompi_h3c11f04_1103
#   icu                        pkgs/main::icu-58.2-h9c2bf20_1 --> conda-forge::icu-64.2-he1b5a44_1
#   idna                           pkgs/main::idna-2.7-py36_0 --> conda-forge::idna-2.8-py36_1000
#   intel-openmp                                   2018.0.3-0 --> 2019.4-243
#   ipykernel          pkgs/main::ipykernel-5.1.0-py36h39e3c~ --> conda-forge::ipykernel-5.1.2-py36h5ca1d4c_0
#   ipython                   pkgs/main::ipython-6.5.0-py36_0 --> conda-forge::ipython-7.8.0-py36h5ca1d4c_0
#   ipython_genutils   pkgs/main/linux-64::ipython_genutils-~ --> conda-forge/noarch::ipython_genutils-0.2.0-py_1
#   jedi                        pkgs/main::jedi-0.12.1-py36_0 --> conda-forge::jedi-0.15.1-py36_0
#   jpeg                        pkgs/main::jpeg-9b-h024ee3a_2 --> conda-forge::jpeg-9c-h14c3975_1001
#   jsonschema             pkgs/main::jsonschema-2.6.0-py36_0 --> conda-forge::jsonschema-3.0.2-py36_0
#   jupyter_client     pkgs/main/linux-64::jupyter_client-5.~ --> conda-forge/noarch::jupyter_client-5.3.1-py_0
#   jupyterhub                                   0.8.1-py36_0 --> 1.0.0-py36_0
#   jupyterlab         pkgs/main/linux-64::jupyterlab-0.31.1~ --> conda-forge/noarch::jupyterlab-1.1.2-py_0
#   jupyterlab_launch~ pkgs/main/linux-64::jupyterlab_launch~ --> conda-forge/noarch::jupyterlab_launcher-0.13.1-py_2
#   libffi                 pkgs/main::libffi-3.2.1-hd88cf55_4 --> conda-forge::libffi-3.2.1-he1b5a44_1006
#   libgcc-ng                                8.2.0-hdf63c60_1 --> 9.1.0-hdf63c60_0
#   libsodium          pkgs/main::libsodium-1.0.16-h1bed415_0 --> conda-forge::libsodium-1.0.17-h516909a_0
#   libstdcxx-ng                             8.2.0-hdf63c60_1 --> 9.1.0-hdf63c60_0
#   libuuid               pkgs/main::libuuid-1.0.3-h1bed415_2 --> conda-forge::libuuid-2.32.1-h14c3975_1000
#   libxcb                  pkgs/main::libxcb-1.13-h1bed415_1 --> conda-forge::libxcb-1.13-h14c3975_1002
#   libxgboost          pkgs/main::libxgboost-0.72-hf484d3e_0 --> conda-forge::libxgboost-0.90-he1b5a44_2
#   libxml2               pkgs/main::libxml2-2.9.9-he19cac6_0 --> conda-forge::libxml2-2.9.9-hee79883_5
#   mako                pkgs/main/linux-64::mako-1.0.9-py36_0 --> conda-forge/noarch::mako-1.1.0-py_0
#   matplotlib         pkgs/main::matplotlib-3.0.2-py36h5429~ --> conda-forge::matplotlib-3.1.1-py36_1
#   mistune            pkgs/main::mistune-0.8.4-py36h7b6447c~ --> conda-forge::mistune-0.8.4-py36h14c3975_1000
#   mkl                                            2019.3-199 --> 2019.4-243
#   mkl_fft            pkgs/main::mkl_fft-1.0.12-py36ha843d7~ --> conda-forge::mkl_fft-1.0.14-py36h516909a_1
#   mkl_random         pkgs/main::mkl_random-1.0.2-py36hd81d~ --> conda-forge::mkl_random-1.1.0-py36hb3f55d8_0
#   nb_conda                 pkgs/main::nb_conda-2.2.1-py36_0 --> conda-forge::nb_conda-2.2.1-py36_2
#   nb_conda_kernels   pkgs/main::nb_conda_kernels-2.2.1-py3~ --> conda-forge::nb_conda_kernels-2.2.2-py36_0
#   nbconvert          pkgs/main/noarch::nbconvert-5.5.0-py_0 --> conda-forge/linux-64::nbconvert-5.6.0-py36_1
#   nbformat           pkgs/main/linux-64::nbformat-4.4.0-py~ --> conda-forge/noarch::nbformat-4.4.0-py_1
#   ncurses                 pkgs/main::ncurses-6.1-he6710b0_1 --> conda-forge::ncurses-6.1-hf484d3e_1002
#   networkx           pkgs/main/linux-64::networkx-2.2-py36~ --> conda-forge/noarch::networkx-2.3-py_0
#   nltk                pkgs/main/linux-64::nltk-3.4.1-py36_0 --> conda-forge/noarch::nltk-3.4.4-py_0
#   nodejs                pkgs/main::nodejs-6.11.2-h3db8ef7_0 --> conda-forge::nodejs-11.14.0-he1b5a44_1
#   notebook           pkgs/main::notebook-5.2.2-py36h40a37e~ --> conda-forge::notebook-6.0.1-py36_0
#   numpy              pkgs/main::numpy-1.16.3-py36h7e9f1db_0 --> conda-forge::numpy-1.17.2-py36h95a1406_0
#   openssl              pkgs/main::openssl-1.0.2p-h14c3975_0 --> conda-forge::openssl-1.1.1c-h516909a_0
#   pandas             pkgs/main::pandas-0.23.4-py36h04863e7~ --> conda-forge::pandas-0.25.1-py36hb3f55d8_0
#   pandoc                        pkgs/main::pandoc-2.2.3.2-0 --> conda-forge::pandoc-2.7.3-0
#   parso              pkgs/main/linux-64::parso-0.3.1-py36_0 --> conda-forge/noarch::parso-0.5.1-py_0
#   pexpect                   pkgs/main::pexpect-4.6.0-py36_0 --> conda-forge::pexpect-4.7.0-py36_0
#   pickleshare           pkgs/main::pickleshare-0.7.4-py36_0 --> conda-forge::pickleshare-0.7.5-py36_1000
#   pip                          pkgs/main::pip-10.0.1-py36_0 --> conda-forge::pip-19.2.3-py36_0
#   plotly             pkgs/main/linux-64::plotly-3.1.0-py36~ --> conda-forge/noarch::plotly-4.1.1-py_0
#   prompt_toolkit     pkgs/main/linux-64::prompt_toolkit-1.~ --> conda-forge/noarch::prompt_toolkit-2.0.9-py_0
#   ptyprocess         pkgs/main/linux-64::ptyprocess-0.6.0-~ --> conda-forge/noarch::ptyprocess-0.6.0-py_1001
#   py-xgboost         pkgs/main::py-xgboost-0.72-py36hf484d~ --> conda-forge::py-xgboost-0.90-py36he1b5a44_2
#   py4j               pkgs/main/linux-64::py4j-0.10.7-py36_0 --> conda-forge/noarch::py4j-0.10.7-py_1
#   pycparser                pkgs/main::pycparser-2.18-py36_1 --> conda-forge::pycparser-2.19-py36_1
#   pydotplus          pkgs/main/linux-64::pydotplus-2.0.2-p~ --> conda-forge/noarch::pydotplus-2.0.2-pyhd1c1de3_3
#   pygments           pkgs/main/linux-64::pygments-2.2.0-py~ --> conda-forge/noarch::pygments-2.4.2-py_0
#   pyopenssl              pkgs/main::pyopenssl-18.0.0-py36_0 --> conda-forge::pyopenssl-19.0.0-py36_0
#   pyparsing                 pkgs/main::pyparsing-2.4.0-py_0 --> conda-forge::pyparsing-2.4.2-py_0
#   pyqt                 pkgs/main::pyqt-5.9.2-py36h05f1152_2 --> conda-forge::pyqt-5.9.2-py36hcca6a23_3
#   pysocks                   pkgs/main::pysocks-1.6.8-py36_0 --> conda-forge::pysocks-1.7.0-py36_0
#   pyspark            pkgs/main/linux-64::pyspark-2.4.0-py3~ --> conda-forge/noarch::pyspark-2.4.4-py_0
#   python                 pkgs/main::python-3.6.6-hc3d631a_0 --> conda-forge::python-3.6.7-h357f687_1005
#   python-oauth2      pkgs/main/linux-64::python-oauth2-1.1~ --> conda-forge/noarch::python-oauth2-1.1.1-py_0
#   pytz               pkgs/main/linux-64::pytz-2018.5-py36_0 --> conda-forge/noarch::pytz-2019.2-py_0
#   pyzmq              pkgs/main::pyzmq-18.0.0-py36he6710b0_0 --> conda-forge::pyzmq-18.0.2-py36h1768529_2
#   qt                         pkgs/main::qt-5.9.6-h8703b6f_2 --> conda-forge::qt-5.9.7-h0c104cb_3
#   readline               pkgs/main::readline-7.0-h7b6447c_5 --> conda-forge::readline-8.0-hf8c457e_0
#   requests                pkgs/main::requests-2.19.1-py36_0 --> conda-forge::requests-2.22.0-py36_1
#   s3transfer             pkgs/main::s3transfer-0.2.0-py36_0 --> conda-forge::s3transfer-0.2.1-py36_0
#   scikit-learn       pkgs/main::scikit-learn-0.20.2-py36hd~ --> conda-forge::scikit-learn-0.21.3-py36hcdab131_0
#   scipy               pkgs/main::scipy-1.1.0-py36h7c811a0_2 --> conda-forge::scipy-1.3.1-py36h921218d_2
#   seaborn            pkgs/main/linux-64::seaborn-0.9.0-py3~ --> conda-forge/noarch::seaborn-0.9.0-py_1
#   setuptools            pkgs/main::setuptools-40.0.0-py36_0 --> conda-forge::setuptools-41.2.0-py36_0
#   sip                  pkgs/main::sip-4.19.8-py36hf484d3e_0 --> conda-forge::sip-4.19.8-py36hf484d3e_1000
#   six                          pkgs/main::six-1.11.0-py36_1 --> conda-forge::six-1.12.0-py36_1000
#   smart_open               pkgs/main::smart_open-1.8.2-py_0 --> conda-forge::smart_open-1.8.4-py_0
#   soupsieve                 pkgs/main::soupsieve-1.8-py36_0 --> conda-forge::soupsieve-1.9.3-py36_0
#   sqlalchemy         pkgs/main::sqlalchemy-1.3.3-py36h7b64~ --> conda-forge::sqlalchemy-1.3.8-py36h516909a_0
#   sqlite                pkgs/main::sqlite-3.24.0-h84994c4_0 --> conda-forge::sqlite-3.29.0-hcee41ef_1
#   statsmodels        pkgs/main::statsmodels-0.9.0-py36h035~ --> conda-forge::statsmodels-0.10.1-py36hc1659b7_0
#   testpath           pkgs/main/linux-64::testpath-0.4.2-py~ --> conda-forge/noarch::testpath-0.4.2-py_1001
#   tk                         pkgs/main::tk-8.6.8-hbc83047_0 --> conda-forge::tk-8.6.9-hed695b0_1002
#   tornado                   pkgs/main::tornado-4.5.3-py36_0 --> conda-forge::tornado-6.0.3-py36h516909a_0
#   tqdm               pkgs/main/linux-64::tqdm-4.31.1-py36_1 --> conda-forge/noarch::tqdm-4.35.0-py_0
#   traitlets               pkgs/main::traitlets-4.3.2-py36_0 --> conda-forge::traitlets-4.3.2-py36_1000
#   urllib3                    pkgs/main::urllib3-1.23-py36_0 --> conda-forge::urllib3-1.25.3-py36_0
#   wcwidth            pkgs/main/linux-64::wcwidth-0.1.7-py3~ --> conda-forge/noarch::wcwidth-0.1.7-py_1
#   wheel                      pkgs/main::wheel-0.31.1-py36_0 --> conda-forge::wheel-0.33.6-py36_0
#   xlrd                pkgs/main/linux-64::xlrd-1.1.0-py36_1 --> conda-forge/noarch::xlrd-1.2.0-py_0
#   xz                         pkgs/main::xz-5.2.4-h14c3975_4 --> conda-forge::xz-5.2.4-h14c3975_1001
#   zeromq                 pkgs/main::zeromq-4.3.1-he6710b0_3 --> conda-forge::zeromq-4.3.2-he1b5a44_2
#   zlib                    pkgs/main::zlib-1.2.11-h7b6447c_3 --> conda-forge::zlib-1.2.11-h516909a_1005
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   backcall           pkgs/main/linux-64::backcall-0.1.0-py~ --> conda-forge/noarch::backcall-0.1.0-py_0
#   blas                              pkgs/main::blas-1.0-mkl --> conda-forge::blas-1.0-openblas
#   bleach             pkgs/main/linux-64::bleach-3.1.0-py36~ --> conda-forge/noarch::bleach-3.1.0-py_0
#   boto               pkgs/main/linux-64::boto-2.49.0-py36_0 --> conda-forge/noarch::boto-2.49.0-py_0
#   bz2file            pkgs/main/linux-64::bz2file-0.98-py36~ --> conda-forge/noarch::bz2file-0.98-py_0
#   dbus                    pkgs/main::dbus-1.13.6-h746ee38_0 --> conda-forge::dbus-1.13.6-he372182_0
#   defusedxml               pkgs/main::defusedxml-0.6.0-py_0 --> conda-forge::defusedxml-0.5.0-py_1
#   expat                   pkgs/main::expat-2.2.6-he6710b0_0 --> conda-forge::expat-2.2.5-he1b5a44_1003
#   jinja2             pkgs/main/linux-64::jinja2-2.10.1-py3~ --> conda-forge/noarch::jinja2-2.10.1-py_0
#   jmespath                                        pkgs/main --> conda-forge
#   jupyter_core       pkgs/main/linux-64::jupyter_core-4.4.~ --> conda-forge/noarch::jupyter_core-4.4.0-py_0
#   kiwisolver         pkgs/main::kiwisolver-1.1.0-py36he671~ --> conda-forge::kiwisolver-1.1.0-py36hc9558a2_0
#   libedit            pkgs/main::libedit-3.1.20181209-hc058~ --> conda-forge::libedit-3.1.20170329-hf8c457e_1001
#   libgcc                                          pkgs/main --> conda-forge
#   libpng                pkgs/main::libpng-1.6.37-hbc83047_0 --> conda-forge::libpng-1.6.37-hed695b0_0
#   markupsafe         pkgs/main::markupsafe-1.1.1-py36h7b64~ --> conda-forge::markupsafe-1.1.1-py36h14c3975_0
#   pamela                                          pkgs/main --> conda-forge
#   pandocfilters      pkgs/main/linux-64::pandocfilters-1.4~ --> conda-forge/noarch::pandocfilters-1.4.2-py_1
#   patsy              pkgs/main/linux-64::patsy-0.5.1-py36_0 --> conda-forge/noarch::patsy-0.5.1-py_0
#   pcre                      pkgs/main::pcre-8.43-he6710b0_0 --> conda-forge::pcre-8.41-hf484d3e_1003
#   python-dateutil    pkgs/main/linux-64::python-dateutil-2~ --> conda-forge/noarch::python-dateutil-2.8.0-py_0
#   python-editor                                   pkgs/main --> conda-forge
#   retrying           pkgs/main/linux-64::retrying-1.3.3-py~ --> conda-forge/noarch::retrying-1.3.3-py_2
#   simplegeneric      pkgs/main/linux-64::simplegeneric-0.8~ --> conda-forge/noarch::simplegeneric-0.8.1-py_1
#   terminado                                       pkgs/main --> conda-forge
#   webencodings       pkgs/main/linux-64::webencodings-0.5.~ --> conda-forge/noarch::webencodings-0.5.1-py_1
#
# The following packages will be DOWNGRADED:
#
#   numpy-base                          1.16.3-py36hde5b4d6_0 --> 1.15.0-py36hc937464_0
#
#
#
# Downloading and Extracting Packages
# tornado-6.0.3        | 636 KB    | ##################################### | 100%
# nltk-3.4.4           | 1.1 MB    | ##################################### | 100%
# mkl_random-1.1.0     | 366 KB    | ##################################### | 100%
# scikit-learn-0.21.3  | 6.7 MB    | ##################################### | 100%
# fribidi-1.0.5        | 112 KB    | ##################################### | 100%
# cffi-1.12.3          | 218 KB    | ##################################### | 100%
# python-dateutil-2.8. | 219 KB    | ##################################### | 100%
# libopenblas-0.3.2    | 7.7 MB    | ##################################### | 100%
# libuuid-2.32.1       | 26 KB     | ##################################### | 100%
# docutils-0.15.2      | 736 KB    | ##################################### | 100%
# jedi-0.15.1          | 717 KB    | ##################################### | 100%
# pycurl-7.43.0.2      | 68 KB     | ##################################### | 100%
# traitlets-4.3.2      | 131 KB    | ##################################### | 100%
# libsodium-1.0.17     | 330 KB    | ##################################### | 100%
# cython-0.29.13       | 2.2 MB    | ##################################### | 100%
# retrying-1.3.3       | 11 KB     | ##################################### | 100%
# xorg-renderproto-0.1 | 8 KB      | ##################################### | 100%
# ptyprocess-0.6.0     | 15 KB     | ##################################### | 100%
# py4j-0.10.7          | 177 KB    | ##################################### | 100%
# jupyterlab_launcher- | 20 KB     | ##################################### | 100%
# cairo-1.16.0         | 1.5 MB    | ##################################### | 100%
# numpy-1.17.2         | 5.2 MB    | ##################################### | 100%
# nb_conda_kernels-2.2 | 32 KB     | ##################################### | 100%
# xorg-libxext-1.3.4   | 51 KB     | ##################################### | 100%
# jmespath-0.9.4       | 20 KB     | ##################################### | 100%
# networkx-2.3         | 1.1 MB    | ##################################### | 100%
# decorator-4.4.0      | 11 KB     | ##################################### | 100%
# xorg-xproto-7.0.31   | 72 KB     | ##################################### | 100%
# pycparser-2.19       | 173 KB    | ##################################### | 100%
# numpy-base-1.15.0    | 4.1 MB    | ##################################### | 100%
# xorg-libsm-1.2.3     | 25 KB     | ##################################### | 100%
# python-3.6.7         | 34.6 MB   | ##################################### | 100%
# tk-8.6.9             | 3.2 MB    | ##################################### | 100%
# sip-4.19.8           | 290 KB    | ##################################### | 100%
# harfbuzz-2.4.0       | 1.5 MB    | ##################################### | 100%
# libxgboost-0.90      | 2.4 MB    | ##################################### | 100%
# setuptools-41.2.0    | 634 KB    | ##################################### | 100%
# statsmodels-0.10.1   | 9.6 MB    | ##################################### | 100%
# _py-xgboost-mutex-2. | 8 KB      | ##################################### | 100%
# fontconfig-2.13.1    | 340 KB    | ##################################### | 100%
# xorg-libxrender-0.9. | 31 KB     | ##################################### | 100%
# alembic-1.1.0        | 98 KB     | ##################################### | 100%
# krb5-1.16.3          | 1.4 MB    | ##################################### | 100%
# ipython_genutils-0.2 | 21 KB     | ##################################### | 100%
# jupyterlab-1.1.2     | 11.7 MB   | ##################################### | 100%
# icu-64.2             | 12.6 MB   | ##################################### | 100%
# liblapack-3.8.0      | 2.9 MB    | ##################################### | 100%
# pyopenssl-19.0.0     | 81 KB     | ##################################### | 100%
# attrs-19.1.0         | 32 KB     | ##################################### | 100%
# xorg-libxpm-3.5.12   | 63 KB     | ##################################### | 100%
# ipykernel-5.1.2      | 159 KB    | ##################################### | 100%
# libtool-2.4.6        | 512 KB    | ##################################### | 100%
# libcurl-7.65.3       | 575 KB    | ##################################### | 100%
# pysocks-1.7.0        | 26 KB     | ##################################### | 100%
# mkl_fft-1.0.14       | 170 KB    | ##################################### | 100%
# ipython-7.8.0        | 1.1 MB    | ##################################### | 100%
# pydotplus-2.0.2      | 23 KB     | ##################################### | 100%
# gstreamer-1.14.5     | 4.5 MB    | ##################################### | 100%
# jupyterlab_server-1. | 23 KB     | ##################################### | 100%
# nodejs-11.14.0       | 16.6 MB   | ##################################### | 100%
# py-xgboost-0.90      | 73 KB     | ##################################### | 100%
# xorg-libice-1.0.10   | 57 KB     | ##################################### | 100%
# bleach-3.1.0         | 110 KB    | ##################################### | 100%
# readline-8.0         | 441 KB    | ##################################### | 100%
# simplegeneric-0.8.1  | 7 KB      | ##################################### | 100%
# pyqt-5.9.2           | 5.7 MB    | ##################################### | 100%
# chardet-3.0.4        | 190 KB    | ##################################### | 100%
# urllib3-1.25.3       | 187 KB    | ##################################### | 100%
# prompt_toolkit-2.0.9 | 222 KB    | ##################################### | 100%
# asn1crypto-0.24.0    | 154 KB    | ##################################### | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ##################################### | 100%
# freetype-2.10.0      | 884 KB    | ##################################### | 100%
# pixman-0.38.0        | 594 KB    | ##################################### | 100%
# pyrsistent-0.15.4    | 89 KB     | ##################################### | 100%
# pyjwt-1.7.1          | 17 KB     | ##################################### | 100%
# jpeg-9c              | 251 KB    | ##################################### | 100%
# pandocfilters-1.4.2  | 9 KB      | ##################################### | 100%
# seaborn-0.9.0        | 163 KB    | ##################################### | 100%
# libpng-1.6.37        | 343 KB    | ##################################### | 100%
# joblib-0.13.2        | 180 KB    | ##################################### | 100%
# jsonschema-3.0.2     | 87 KB     | ##################################### | 100%
# dbus-1.13.6          | 602 KB    | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# sqlalchemy-1.3.8     | 1.7 MB    | ##################################### | 100%
# testpath-0.4.2       | 85 KB     | ##################################### | 100%
# glib-2.58.3          | 3.3 MB    | ##################################### | 100%
# botocore-1.12.224    | 3.4 MB    | ##################################### | 100%
# gst-plugins-base-1.1 | 6.8 MB    | ##################################### | 100%
# xorg-libxt-1.1.5     | 367 KB    | ##################################### | 100%
# wheel-0.33.6         | 35 KB     | ##################################### | 100%
# zeromq-4.3.2         | 668 KB    | ##################################### | 100%
# pamela-1.0.0         | 9 KB      | ##################################### | 100%
# defusedxml-0.5.0     | 20 KB     | ##################################### | 100%
# libssh2-1.8.2        | 257 KB    | ##################################### | 100%
# pyzmq-18.0.2         | 513 KB    | ##################################### | 100%
# libgcc-7.2.0         | 304 KB    | ##################################### | 100%
# xorg-kbproto-1.0.7   | 26 KB     | ##################################### | 100%
# zlib-1.2.11          | 105 KB    | ##################################### | 100%
# json5-0.8.5          | 24 KB     | ##################################### | 100%
# pytz-2019.2          | 228 KB    | ##################################### | 100%
# h5py-2.9.0           | 1.2 MB    | ##################################### | 100%
# scipy-1.3.1          | 18.1 MB   | ##################################### | 100%
# requests-2.22.0      | 84 KB     | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# libblas-3.8.0        | 181 KB    | ##################################### | 100%
# graphviz-2.40.1      | 6.4 MB    | ##################################### | 100%
# soupsieve-1.9.3      | 57 KB     | ##################################### | 100%
# s3transfer-0.2.1     | 91 KB     | ##################################### | 100%
# async_generator-1.10 | 18 KB     | ##################################### | 100%
# nbconvert-5.6.0      | 465 KB    | ##################################### | 100%
# pandoc-2.7.3         | 22.4 MB   | ##################################### | 100%
# xorg-xextproto-7.3.0 | 27 KB     | ##################################### | 100%
# jinja2-2.10.1        | 91 KB     | ##################################### | 100%
# libcblas-3.8.0       | 47 KB     | ##################################### | 100%
# pyspark-2.4.4        | 204.9 MB  | ##################################### | 100%
# wcwidth-0.1.7        | 17 KB     | ##################################### | 100%
# prometheus_client-0. | 38 KB     | ##################################### | 100%
# xorg-libx11-1.6.8    | 907 KB    | ##################################### | 100%
# nb_conda-2.2.1       | 35 KB     | ##################################### | 100%
# cryptography-vectors | 30.6 MB   | ##################################### | 100%
# patsy-0.5.1          | 187 KB    | ##################################### | 100%
# zstd-1.4.0           | 928 KB    | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 18 KB     | ##################################### | 100%
# tqdm-4.35.0          | 42 KB     | ##################################### | 100%
# nbformat-4.4.0       | 91 KB     | ##################################### | 100%
# pexpect-4.7.0        | 78 KB     | ##################################### | 100%
# terminado-0.8.2      | 23 KB     | ##################################### | 100%
# matplotlib-base-3.1. | 6.7 MB    | ##################################### | 100%
# mkl-2019.4           | 204.1 MB  | ##################################### | 100%
# pcre-8.41            | 249 KB    | ##################################### | 100%
# pandas-0.25.1        | 11.4 MB   | ##################################### | 100%
# certipy-0.1.3        | 17 KB     | ##################################### | 100%
# boto3-1.9.224        | 69 KB     | ##################################### | 100%
# gensim-3.7.3         | 22.7 MB   | ##################################### | 100%
# idna-2.8             | 132 KB    | ##################################### | 100%
# gmp-6.1.2            | 751 KB    | ##################################### | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ##################################### | 100%
# xlrd-1.2.0           | 108 KB    | ##################################### | 100%
# bz2file-0.98         | 9 KB      | ##################################### | 100%
# intel-openmp-2019.4  | 876 KB    | ##################################### | 100%
# pyparsing-2.4.2      | 57 KB     | ##################################### | 100%
# six-1.12.0           | 22 KB     | ##################################### | 100%
# jupyter_core-4.4.0   | 44 KB     | ##################################### | 100%
# pygments-2.4.2       | 661 KB    | ##################################### | 100%
# python-editor-1.0.4  | 9 KB      | ##################################### | 100%
# libxcb-1.13          | 396 KB    | ##################################### | 100%
# cryptography-2.7     | 607 KB    | ##################################### | 100%
# kiwisolver-1.1.0     | 86 KB     | ##################################### | 100%
# mako-1.1.0           | 57 KB     | ##################################### | 100%
# send2trash-1.5.0     | 12 KB     | ##################################### | 100%
# blas-1.0             | 1 KB      | ##################################### | 100%
# smart_open-1.8.4     | 53 KB     | ##################################### | 100%
# gettext-0.19.8.1     | 3.6 MB    | ##################################### | 100%
# qt-5.9.7             | 80.8 MB   | ##################################### | 100%
# jupyterhub-1.0.0     | 1.8 MB    | ##################################### | 100%
# hdf5-1.10.5          | 3.1 MB    | ##################################### | 100%
# pango-1.42.4         | 517 KB    | ##################################### | 100%
# python-oauth2-1.1.1  | 40 KB     | ##################################### | 100%
# markupsafe-1.1.1     | 26 KB     | ##################################### | 100%
# mistune-0.8.4        | 53 KB     | ##################################### | 100%
# webencodings-0.5.1   | 12 KB     | ##################################### | 100%
# graphite2-1.3.13     | 109 KB    | ##################################### | 100%
# sqlite-3.29.0        | 1.9 MB    | ##################################### | 100%
# libiconv-1.15        | 2.0 MB    | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# backcall-0.1.0       | 13 KB     | ##################################### | 100%
# cycler-0.10.0        | 8 KB      | ##################################### | 100%
# notebook-6.0.1       | 6.0 MB    | ##################################### | 100%
# matplotlib-3.1.1     | 6 KB      | ##################################### | 100%
# lz4-c-1.8.3          | 187 KB    | ##################################### | 100%
# blinker-1.4          | 13 KB     | ##################################### | 100%
# beautifulsoup4-4.8.0 | 144 KB    | ##################################### | 100%
# expat-2.2.5          | 191 KB    | ##################################### | 100%
# pickleshare-0.7.5    | 12 KB     | ##################################### | 100%
# jupyter_client-5.3.1 | 64 KB     | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# boto-2.49.0          | 838 KB    | ##################################### | 100%
# configurable-http-pr | 866 KB    | ##################################### | 100%
# openblas-0.3.4       | 15.8 MB   | ##################################### | 100%
# plotly-4.1.1         | 4.0 MB    | ##################################### | 100%
# oauthlib-3.0.1       | 82 KB     | ##################################### | 100%
# mkl-service-2.3.0    | 64 KB     | ##################################### | 100%
# entrypoints-0.3      | 12 KB     | ##################################### | 100%
# libtiff-4.0.10       | 587 KB    | ##################################### | 100%
# parso-0.5.1          | 65 KB     | ##################################### | 100%
# pip-19.2.3           | 1.9 MB    | ##################################### | 100%
# libxml2-2.9.9        | 1.3 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: - b'+ /opt/conda/envs/learn-env/bin/jupyter-nbextension disable nb_conda --py --sys-prefix\nDisabling notebook extension nb_conda/main...\n      - Validating: \x1bOK\x1b\nDisabling tree extension nb_conda/tree...\n      - Validating: \x1bOK\x1b\n+ /opt/conda/envs/learn-env/bin/jupyter-serverextension disable nb_conda --py --sys-prefix\nDisabling: nb_conda\n- Writing config: /opt/conda/envs/learn-env/etc/jupyter\n'
# \ b'Disabling nb_conda_kernels...\nStatus: disabled\n'
# - b'Enabling nb_conda_kernels...\nStatus: enabled\n'
# - b'Enabling notebook extension nb_conda/main...\n      - Validating: \x1bOK\x1b\nEnabling tree extension nb_conda/tree...\n      - Validating: \x1bOK\x1b\nEnabling: nb_conda\n- Writing config: /opt/conda/envs/learn-env/etc/jupyter\n    - Validating...\n      nb_conda 2.2.1 \x1bOK\x1b\n'
# done

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',data=tips)
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Very cool! That visualization contains _a lot_ of information, and it does it in a way that is easy to interpret and understand. Best of all, it didn't take much work on our part--all we had to do was tell the function the name of the column to use for the x axis, the name of the column to use for the y axis, and the name of the variable to condition on, as denoted by the two different colors.
#
# If we want to get even more ambitious, we can create mutiple subplots by using the `row=` and `column=` parameters, as well!
#
# Run the cell below to see an example, and see if you can figure out how the code works.

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker",
           col="time", row="sex", data=tips)
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Summary
#
# In this lab, we explored the **_Seaborn_** library, and explored the sorts of data visualizations we can create with it!
